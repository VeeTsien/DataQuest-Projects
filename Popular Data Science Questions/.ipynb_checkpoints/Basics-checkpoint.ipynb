# %% [markdown]
# # Popular Data Science Questions
# Our goal in this project is to use [Data Science Stack Exchange](https://datascience.stackexchange.com/) to determine what content should a data science education company create, based on interest by subject.

# %% [markdown]
# In exploration of the DSSE database Schema from [DSSE Data Explorer](https://data.stackexchange.com/datascience/query/new), we found a few tables promising in finding the most popular content:
#
# * Posts
# * Comments
# * PostTags
# * Tags
# * TagSynonyms
# * Votes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
posts = pd.read_csv('2019_questions.csv')

# %%
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8839 entries, 0 to 8838
# Data columns (total 7 columns):
# Id               8839 non-null int64
# CreationDate     8839 non-null object
# Score            8839 non-null int64
# ViewCount        8839 non-null int64
# Tags             8839 non-null object
# AnswerCount      8839 non-null int64
# FavoriteCount    1407 non-null float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 483.5+ KB

# %%
posts.describe(include = 'all')
# Out:
#                   Id         CreationDate        Score     ViewCount  \
# count    8839.000000                 8839  8839.000000   8839.000000
# unique           NaN                 8838          NaN           NaN
# top              NaN  2019-09-25 18:32:47          NaN           NaN
# freq             NaN                    2          NaN           NaN
# mean    54724.172870                  NaN     0.870687    171.548026
# std      6507.618509                  NaN     1.410255    772.813626
# min     43363.000000                  NaN    -2.000000      2.000000
# 25%     48917.500000                  NaN     0.000000     22.000000
# 50%     54833.000000                  NaN     1.000000     40.000000
# 75%     60674.500000                  NaN     1.000000     98.000000
# max     65675.000000                  NaN    45.000000  33203.000000
#
#                       Tags  AnswerCount  FavoriteCount
# count                 8839  8839.000000    1407.000000
# unique                6462          NaN            NaN
# top     <machine-learning>          NaN            NaN
# freq                   118          NaN            NaN
# mean                   NaN     0.787985       1.184790
# std                    NaN     0.851146       0.982766
# min                    NaN     0.000000       0.000000
# 25%                    NaN     0.000000       1.000000
# 50%                    NaN     1.000000       1.000000
# 75%                    NaN     1.000000       1.000000
# max                    NaN     9.000000      16.000000

# %%
posts.head()
# Out:
#       Id         CreationDate  Score  ViewCount  \
# 0  44419  2019-01-23 09:21:13      1         21
# 1  44420  2019-01-23 09:34:01      0         25
# 2  44423  2019-01-23 09:58:41      2       1651
# 3  44427  2019-01-23 10:57:09      0         55
# 4  44428  2019-01-23 11:02:15      0         19
#
#                                                 Tags  AnswerCount  \
# 0                    <machine-learning><data-mining>            0
# 1  <machine-learning><regression><linear-regressi...            0
# 2       <python><time-series><forecast><forecasting>            0
# 3              <machine-learning><scikit-learn><pca>            1
# 4           <dataset><bigdata><data><speech-to-text>            0
#
#    FavoriteCount
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
print(posts['FavoriteCount'].unique())
# Out:
# [nan  1.  2.  3.  0. 11.  4.  5.  7.  6. 16.  8.]

# %% [markdown]
# * `FavoriteCount` columns has over 80% missing data. The missing value probably indicates that no user marked the post as 'favorite', we should just fill the NaN values with zeros.
# * `CreateDate` column should be type datetime, `FavoriteCount` should be type int
# * Since `Tags` column has over 6000 unique combinations of tags, we can create a new DataFrame to seperate the tags and explore more.

# %%
posts['FavoriteCount'].fillna(0, inplace = True)

# %%
posts['CreationDate'] = pd.to_datetime(posts['CreationDate'])

# %%
posts['FavoriteCount'] = posts['FavoriteCount'].astype(int)

# %%
posts['Tags'] = posts['Tags'].str.replace(r'(><)', ',').str.replace(r'[<>]','').str.split(',')

# %%
# Find unique tags
tags = []
for t in posts['Tags']:
    for i in t:
       tags.append(i)
unique_tags = pd.Series(tags).unique()
unique_tags.size
# Out:
# 526

# %%
# Count how many times each unique tag was used
tags_count = {}
for ut in unique_tags:
    tags_count[ut] = posts['Tags'].apply(lambda t: True if ut in t else False).sum()

# %%
# Convert tags_count to a Series and sort by descending, find the top 20 used tags
tags_count = pd.Series(tags_count)
top20_used_tags = tags_count.sort_values(ascending = False).head(20)

# %%
# Count how total views in posts with the tags
tags_viewed = {}
for ut in unique_tags:
    tags_viewed[ut] = posts[posts['Tags'].apply(lambda t: True if ut in t else False)]['ViewCount'].sum()

# %%
# Convert tags_viewed to a Series and find the top 20 viewed tags 
tags_viewed = pd.Series(tags_viewed).sort_values(ascending = False)
top20_viewed_tags = tags_viewed.head(20)
top20_viewed_tags
# Out:
# python              537585
# machine-learning    388499
# keras               268608
# deep-learning       233628
# pandas              201787
# neural-network      185367
# scikit-learn        128110
# tensorflow          121369
# classification      104457
# dataframe            89352
# lstm                 74458
# nlp                  71382
# cnn                  70349
# time-series          64134
# numpy                49767
# regression           49451
# dataset              43151
# pytorch              40240
# csv                  38654
# clustering           33928
# dtype: int64

# %%
# Make bar plots for top20_used_tags and top20_viewed_tags
# Set seaborn style
sns.set(style = 'whitegrid')
# Setup plot canvas 
f, (ax1, ax2) = plt.subplots(2,1, figsize=(15, 15))

# Bar plots for top20_used_tags
top_used_tags = sns.barplot(y = top20_used_tags.index, x = top20_used_tags, palette="Blues_r", ax = ax1, alpha = 0.6)
ax1.set_title('Top20 Used Tags')
# Bar plots for top20_viewed_tags
top_viewed_tags = top_used_tags = sns.barplot(y = top20_viewed_tags.index, x = top20_viewed_tags, palette= 'BuGn_r', ax = ax2, alpha = 0.6)
ax2.set_title('Top20 Viewed Tags')

# Beautify plot
sns.despine(fig = f, top = True, bottom = True)
ax1_range = range(0, len(top20_used_tags))
ax1.plot(top20_used_tags, ax1_range, "o", markersize=15, color='#007ACC', alpha=0.6)
ax2_range = range(0, len(top20_viewed_tags))
ax2.plot(top20_viewed_tags, ax2_range, "o", markersize=15, color='#239023', alpha=0.6)

# light_palette = sns.light_palette((210, 90, 60), input="husl")
# for item in top_used_tags.get_xticklabels():
#     item.set_rotation(90)

# %%
# Explore correlations between tags 
top_tags = pd.concat([top20_used_tags,top20_viewed_tags], axis = 1, join = 'outer', ignore_index = True)
top_tags.reset_index(inplace=True)
top_tags.rename(columns={'index':'tags', 0:'used_ct', 1:'viewed_ct'}, inplace=True)
top_tags.corr()
# Out:
#             used_ct  viewed_ct
# used_ct    1.000000   0.851466
# viewed_ct  0.851466   1.000000

# %%
# Find out relationship between pair of tags by counting how many times a pair of tags are used together.
# Set up dataframe with tags as index & columns 
pair_tag = pd.DataFrame(columns = unique_tags, index = unique_tags)
pair_tag.iloc[:5,:5]
# Out:
#                   machine-learning data-mining regression linear-regression  \
# machine-learning               NaN         NaN        NaN               NaN
# data-mining                    NaN         NaN        NaN               NaN
# regression                     NaN         NaN        NaN               NaN
# linear-regression              NaN         NaN        NaN               NaN
# regularization                 NaN         NaN        NaN               NaN
#
#                   regularization
# machine-learning             NaN
# data-mining                  NaN
# regression                   NaN
# linear-regression            NaN
# regularization               NaN

# %%
# Incrementor for tags in a row was used in posts['Tags']
pair_tag.fillna(0, inplace = True)

# `t` is a list of tags 
for t in posts['Tags']:
        pair_tag.loc[t,t] += 1
pair_tag
# Out:
#                            machine-learning  data-mining  regression  \
# machine-learning                       2693           95         119
# data-mining                              95          217           3
# regression                              119            3         347
# linear-regression                        68            1          35
# regularization                           20            0           2
# python                                  499           27          59
# time-series                             131           11          24
# forecast                                  9            0           1
# forecasting                              29            0           6
# scikit-learn                            188            2          37
# pca                                      24            2           0
# dataset                                  99           30           6
# bigdata                                  19            8           1
# data                                     54           23           6
# speech-to-text                            2            0           0
# fuzzy-logic                               4            0           0
# anomaly-detection                        39            5           1
# online-learning                           4            0           0
# matrix-factorisation                     10            0           1
# correlation                              27            1           7
# naive-bayes-classifier                   12            2           0
# deep-learning                           429           24          21
# keras                                   195            1          31
# cnn                                     124            2           6
# theory                                    4            0           0
# gradient-descent                         39            0           3
# nlp                                     113            8           2
# clustering                               61            3           2
# feature-extraction                       27            4           3
# encoding                                 19            1           1
# ...                                     ...          ...         ...
# efficiency                                0            0           0
# auc                                       1            0           0
# categorical-encoding                      0            0           0
# helmert-coding                            0            0           0
# james-stein-encoder                       0            0           0
# one-hot-encoding                          2            0           0
# word                                      0            0           0
# predict                                   1            0           0
# nl2sql                                    0            0           0
# allennlp                                  0            0           0
# c++                                       0            0           0
# community                                 0            0           0
# library                                   0            0           0
# google-prediction-api                     0            0           0
# pgm                                       0            0           0
# adaboost                                  0            0           0
# frequentist                               0            0           0
# google-cloud                              0            0           0
# multivariate-distribution                 0            0           0
# spyder                                    0            0           0
# haar-cascade                              0            0           0
# gru                                       0            0           0
# pattern-recognition                       1            0           0
# text-classification                       0            0           0
# parquet                                   0            0           0
# encoder                                   0            0           0
# label-smoothing                           0            0           0
# label-flipping                            0            0           0
# 3d-object-detection                       0            0           0
# kitti-dataset                             0            0           0
#
#                            linear-regression  regularization  python  \
# machine-learning                          68              20     499
# data-mining                                1               0      27
# regression                                35               2      59
# linear-regression                        175               1      30
# regularization                             1              50       1
# python                                    30               1    1814
# time-series                               10               0     105
# forecast                                   1               0       6
# forecasting                                2               0      23
# scikit-learn                              27               1     235
# pca                                        0               0      12
# dataset                                    2               0      53
# bigdata                                    0               0      14
# data                                       2               1      35
# speech-to-text                             0               0       0
# fuzzy-logic                                0               0       1
# anomaly-detection                          0               0      22
# online-learning                            0               0       0
# matrix-factorisation                       1               5       1
# correlation                                2               0      14
# naive-bayes-classifier                     1               0       5
# deep-learning                              4               5     160
# keras                                      7               5     280
# cnn                                        0               4      62
# theory                                     0               0       0
# gradient-descent                          10               3      10
# nlp                                        1               0      71
# clustering                                 2               0      45
# feature-extraction                         0               0      12
# encoding                                   1               0       9
# ...                                      ...             ...     ...
# efficiency                                 0               0       0
# auc                                        0               0       0
# categorical-encoding                       0               0       1
# helmert-coding                             0               0       0
# james-stein-encoder                        0               0       0
# one-hot-encoding                           0               0       2
# word                                       0               0       1
# predict                                    0               0       0
# nl2sql                                     0               0       0
# allennlp                                   0               0       0
# c++                                        0               0       0
# community                                  0               0       1
# library                                    0               0       1
# google-prediction-api                      0               0       0
# pgm                                        0               0       0
# adaboost                                   0               0       1
# frequentist                                0               0       0
# google-cloud                               0               0       0
# multivariate-distribution                  0               0       0
# spyder                                     0               0       1
# haar-cascade                               0               0       0
# gru                                        0               0       0
# pattern-recognition                        0               0       0
# text-classification                        0               0       0
# parquet                                    0               0       0
# encoder                                    0               0       0
# label-smoothing                            0               0       0
# label-flipping                             0               0       0
# 3d-object-detection                        0               0       0
# kitti-dataset                              0               0       0
#
#                            time-series  forecast  forecasting  scikit-learn  \
# machine-learning                   131         9           29           188
# data-mining                         11         0            0             2
# regression                          24         1            6            37
# linear-regression                   10         1            2            27
# regularization                       0         0            0             1
# python                             105         6           23           235
# time-series                        466        25           59            12
# forecast                            25        34            8             0
# forecasting                         59         8           85             1
# scikit-learn                        12         0            1           540
# pca                                  2         1            0            11
# dataset                              6         0            3             9
# bigdata                              1         0            0             1
# data                                 6         0            0             4
# speech-to-text                       0         0            0             0
# fuzzy-logic                          0         0            0             0
# anomaly-detection                   25         0            2             7
# online-learning                      2         0            0             2
# matrix-factorisation                 0         0            0             2
# correlation                         10         0            0             1
# naive-bayes-classifier               0         0            0             7
# deep-learning                       44         1            2            16
# keras                               51         1            5            34
# cnn                                  8         0            1             0
# theory                               1         0            0             1
# gradient-descent                     1         0            0             4
# nlp                                  0         0            0            12
# clustering                          20         0            0            24
# feature-extraction                   6         0            1             5
# encoding                             1         0            0             5
# ...                                ...       ...          ...           ...
# efficiency                           0         0            0             0
# auc                                  0         0            0             1
# categorical-encoding                 0         0            0             0
# helmert-coding                       0         0            0             0
# james-stein-encoder                  0         0            0             0
# one-hot-encoding                     0         0            0             0
# word                                 0         0            0             0
# predict                              0         0            0             1
# nl2sql                               0         0            0             0
# allennlp                             0         0            0             0
# c++                                  0         0            0             0
# community                            0         0            0             0
# library                              0         0            0             0
# google-prediction-api                0         0            0             0
# pgm                                  0         0            0             0
# adaboost                             0         0            0             0
# frequentist                          0         0            0             0
# google-cloud                         0         0            0             0
# multivariate-distribution            0         0            0             0
# spyder                               0         0            0             0
# haar-cascade                         0         0            0             0
# gru                                  1         0            0             0
# pattern-recognition                  0         0            0             0
# text-classification                  0         0            0             0
# parquet                              0         0            0             0
# encoder                              0         0            0             0
# label-smoothing                      0         0            0             0
# label-flipping                       0         0            0             0
# 3d-object-detection                  0         0            0             0
# kitti-dataset                        0         0            0             0
#
#                                ...        haar-cascade  gru  \
# machine-learning               ...                   0    0
# data-mining                    ...                   0    0
# regression                     ...                   0    0
# linear-regression              ...                   0    0
# regularization                 ...                   0    0
# python                         ...                   0    0
# time-series                    ...                   0    1
# forecast                       ...                   0    0
# forecasting                    ...                   0    0
# scikit-learn                   ...                   0    0
# pca                            ...                   0    0
# dataset                        ...                   0    0
# bigdata                        ...                   0    0
# data                           ...                   0    0
# speech-to-text                 ...                   0    0
# fuzzy-logic                    ...                   0    0
# anomaly-detection              ...                   0    0
# online-learning                ...                   0    0
# matrix-factorisation           ...                   0    0
# correlation                    ...                   0    0
# naive-bayes-classifier         ...                   0    0
# deep-learning                  ...                   0    0
# keras                          ...                   0    1
# cnn                            ...                   0    0
# theory                         ...                   0    0
# gradient-descent               ...                   0    0
# nlp                            ...                   0    0
# clustering                     ...                   0    0
# feature-extraction             ...                   0    0
# encoding                       ...                   0    0
# ...                            ...                 ...  ...
# efficiency                     ...                   0    0
# auc                            ...                   0    0
# categorical-encoding           ...                   0    0
# helmert-coding                 ...                   0    0
# james-stein-encoder            ...                   0    0
# one-hot-encoding               ...                   0    0
# word                           ...                   0    0
# predict                        ...                   0    0
# nl2sql                         ...                   0    0
# allennlp                       ...                   0    0
# c++                            ...                   0    0
# community                      ...                   0    0
# library                        ...                   0    0
# google-prediction-api          ...                   0    0
# pgm                            ...                   0    0
# adaboost                       ...                   0    0
# frequentist                    ...                   0    0
# google-cloud                   ...                   0    0
# multivariate-distribution      ...                   0    0
# spyder                         ...                   0    0
# haar-cascade                   ...                   1    0
# gru                            ...                   0    1
# pattern-recognition            ...                   0    0
# text-classification            ...                   0    0
# parquet                        ...                   0    0
# encoder                        ...                   0    0
# label-smoothing                ...                   0    0
# label-flipping                 ...                   0    0
# 3d-object-detection            ...                   0    0
# kitti-dataset                  ...                   0    0
#
#                            pattern-recognition  text-classification  parquet  \
# machine-learning                             1                    0        0
# data-mining                                  0                    0        0
# regression                                   0                    0        0
# linear-regression                            0                    0        0
# regularization                               0                    0        0
# python                                       0                    0        0
# time-series                                  0                    0        0
# forecast                                     0                    0        0
# forecasting                                  0                    0        0
# scikit-learn                                 0                    0        0
# pca                                          0                    0        0
# dataset                                      0                    0        0
# bigdata                                      0                    0        0
# data                                         0                    0        1
# speech-to-text                               0                    0        0
# fuzzy-logic                                  0                    0        0
# anomaly-detection                            0                    0        0
# online-learning                              0                    0        0
# matrix-factorisation                         0                    0        0
# correlation                                  0                    0        0
# naive-bayes-classifier                       0                    0        0
# deep-learning                                0                    1        0
# keras                                        0                    0        0
# cnn                                          0                    0        0
# theory                                       0                    0        0
# gradient-descent                             0                    0        0
# nlp                                          0                    1        0
# clustering                                   0                    0        0
# feature-extraction                           0                    0        0
# encoding                                     0                    0        0
# ...                                        ...                  ...      ...
# efficiency                                   0                    0        0
# auc                                          0                    0        0
# categorical-encoding                         0                    0        0
# helmert-coding                               0                    0        0
# james-stein-encoder                          0                    0        0
# one-hot-encoding                             0                    0        0
# word                                         0                    0        0
# predict                                      0                    0        0
# nl2sql                                       0                    0        0
# allennlp                                     0                    0        0
# c++                                          0                    0        0
# community                                    0                    0        0
# library                                      0                    0        0
# google-prediction-api                        0                    0        0
# pgm                                          0                    0        0
# adaboost                                     0                    0        0
# frequentist                                  0                    0        0
# google-cloud                                 0                    0        0
# multivariate-distribution                    0                    0        0
# spyder                                       0                    0        0
# haar-cascade                                 0                    0        0
# gru                                          0                    0        0
# pattern-recognition                          1                    0        0
# text-classification                          0                    1        0
# parquet                                      0                    0        1
# encoder                                      0                    0        0
# label-smoothing                              0                    0        0
# label-flipping                               0                    0        0
# 3d-object-detection                          0                    0        0
# kitti-dataset                                0                    0        0
#
#                            encoder  label-smoothing  label-flipping  \
# machine-learning                 0                0               0
# data-mining                      0                0               0
# regression                       0                0               0
# linear-regression                0                0               0
# regularization                   0                0               0
# python                           0                0               0
# time-series                      0                0               0
# forecast                         0                0               0
# forecasting                      0                0               0
# scikit-learn                     0                0               0
# pca                              0                0               0
# dataset                          0                0               0
# bigdata                          0                0               0
# data                             0                0               0
# speech-to-text                   0                0               0
# fuzzy-logic                      0                0               0
# anomaly-detection                0                0               0
# online-learning                  0                0               0
# matrix-factorisation             0                0               0
# correlation                      0                0               0
# naive-bayes-classifier           0                0               0
# deep-learning                    0                0               0
# keras                            0                0               0
# cnn                              0                0               0
# theory                           0                0               0
# gradient-descent                 0                0               0
# nlp                              0                0               0
# clustering                       0                0               0
# feature-extraction               0                0               0
# encoding                         0                0               0
# ...                            ...              ...             ...
# efficiency                       0                0               0
# auc                              0                0               0
# categorical-encoding             0                0               0
# helmert-coding                   0                0               0
# james-stein-encoder              0                0               0
# one-hot-encoding                 0                0               0
# word                             0                0               0
# predict                          0                0               0
# nl2sql                           0                0               0
# allennlp                         0                0               0
# c++                              0                0               0
# community                        0                0               0
# library                          0                0               0
# google-prediction-api            0                0               0
# pgm                              0                0               0
# adaboost                         0                0               0
# frequentist                      0                0               0
# google-cloud                     0                0               0
# multivariate-distribution        0                0               0
# spyder                           0                0               0
# haar-cascade                     0                0               0
# gru                              0                0               0
# pattern-recognition              0                0               0
# text-classification              0                0               0
# parquet                          0                0               0
# encoder                          1                0               0
# label-smoothing                  0                1               1
# label-flipping                   0                1               1
# 3d-object-detection              0                0               0
# kitti-dataset                    0                0               0
#
#                            3d-object-detection  kitti-dataset
# machine-learning                             0              0
# data-mining                                  0              0
# regression                                   0              0
# linear-regression                            0              0
# regularization                               0              0
# python                                       0              0
# time-series                                  0              0
# forecast                                     0              0
# forecasting                                  0              0
# scikit-learn                                 0              0
# pca                                          0              0
# dataset                                      0              0
# bigdata                                      0              0
# data                                         0              0
# speech-to-text                               0              0
# fuzzy-logic                                  0              0
# anomaly-detection                            0              0
# online-learning                              0              0
# matrix-factorisation                         0              0
# correlation                                  0              0
# naive-bayes-classifier                       0              0
# deep-learning                                1              1
# keras                                        0              0
# cnn                                          0              0
# theory                                       0              0
# gradient-descent                             0              0
# nlp                                          0              0
# clustering                                   0              0
# feature-extraction                           0              0
# encoding                                     0              0
# ...                                        ...            ...
# efficiency                                   0              0
# auc                                          0              0
# categorical-encoding                         0              0
# helmert-coding                               0              0
# james-stein-encoder                          0              0
# one-hot-encoding                             0              0
# word                                         0              0
# predict                                      0              0
# nl2sql                                       0              0
# allennlp                                     0              0
# c++                                          0              0
# community                                    0              0
# library                                      0              0
# google-prediction-api                        0              0
# pgm                                          0              0
# adaboost                                     0              0
# frequentist                                  0              0
# google-cloud                                 0              0
# multivariate-distribution                    0              0
# spyder                                       0              0
# haar-cascade                                 0              0
# gru                                          0              0
# pattern-recognition                          0              0
# text-classification                          0              0
# parquet                                      0              0
# encoder                                      0              0
# label-smoothing                              0              0
# label-flipping                               0              0
# 3d-object-detection                          1              1
# kitti-dataset                                1              1
#
# [526 rows x 526 columns]

# %%
# Top20_used_tags relation 
top_used_relation = pair_tag.loc[top20_used_tags.index, top20_used_tags.index]
top_used_relation
# Out:
#                         machine-learning  python  deep-learning  \
# machine-learning                    2693     499            429
# python                               499    1814            160
# deep-learning                        429     160           1220
# neural-network                       366     137            305
# keras                                195     280            247
# classification                       259      98             59
# tensorflow                           106     167            136
# scikit-learn                         188     235             16
# nlp                                  113      71             72
# cnn                                  124      62            160
# time-series                          131     105             44
# lstm                                  71      61            103
# pandas                                62     244              1
# regression                           119      59             21
# dataset                               99      53             32
# r                                     63      24              5
# predictive-modeling                  123      35             32
# clustering                            61      45              2
# statistics                            89      35             12
# machine-learning-model               139      37             19
#
#                         neural-network  keras  classification  tensorflow  \
# machine-learning                   366    195             259         106
# python                             137    280              98         167
# deep-learning                      305    247              59         136
# neural-network                    1055    235              65         108
# keras                              235    935              58         256
# classification                      65     58             685          20
# tensorflow                         108    256              20         584
# scikit-learn                        24     34              47          15
# nlp                                 24     23              35          11
# cnn                                118    116              20          57
# time-series                         33     51              25           9
# lstm                                69    133              20          43
# pandas                               1      3               3           3
# regression                          42     31              34           9
# dataset                             20     13              28           9
# r                                    9     10              10           1
# predictive-modeling                 13     11              27           6
# clustering                           8      0              12           0
# statistics                          11      3              19           0
# machine-learning-model              10     17              21           9
#
#                         scikit-learn  nlp  cnn  time-series  lstm  pandas  \
# machine-learning                 188  113  124          131    71      62
# python                           235   71   62          105    61     244
# deep-learning                     16   72  160           44   103       1
# neural-network                    24   24  118           33    69       1
# keras                             34   23  116           51   133       3
# classification                    47   35   20           25    20       3
# tensorflow                        15   11   57            9    43       3
# scikit-learn                     540   12    0           12     2      37
# nlp                               12  493    7            0    19       3
# cnn                                0    7  489            8    24       1
# time-series                       12    0    8          466    87      19
# lstm                               2   19   24           87   402       7
# pandas                            37    3    1           19     7     354
# regression                        37    2    6           24    11       6
# dataset                            9   11   11            6     7      14
# r                                  1    4    2           22     3       2
# predictive-modeling               12    1    6           31    13       4
# clustering                        24    9    0           20     3       5
# statistics                         6    3    1           22     1       3
# machine-learning-model            18    4    4            7     5       4
#
#                         regression  dataset    r  predictive-modeling  \
# machine-learning               119       99   63                  123
# python                          59       53   24                   35
# deep-learning                   21       32    5                   32
# neural-network                  42       20    9                   13
# keras                           31       13   10                   11
# classification                  34       28   10                   27
# tensorflow                       9        9    1                    6
# scikit-learn                    37        9    1                   12
# nlp                              2       11    4                    1
# cnn                              6       11    2                    6
# time-series                     24        6   22                   31
# lstm                            11        7    3                   13
# pandas                           6       14    2                    4
# regression                     347        6   10                   28
# dataset                          6      340    6                    7
# r                               10        6  268                   13
# predictive-modeling             28        7   13                  265
# clustering                       2        5   16                    0
# statistics                      16       17   16                   16
# machine-learning-model           8       12    7                   21
#
#                         clustering  statistics  machine-learning-model
# machine-learning                61          89                     139
# python                          45          35                      37
# deep-learning                    2          12                      19
# neural-network                   8          11                      10
# keras                            0           3                      17
# classification                  12          19                      21
# tensorflow                       0           0                       9
# scikit-learn                    24           6                      18
# nlp                              9           3                       4
# cnn                              0           1                       4
# time-series                     20          22                       7
# lstm                             3           1                       5
# pandas                           5           3                       4
# regression                       2          16                       8
# dataset                          5          17                      12
# r                               16          16                       7
# predictive-modeling              0          16                      21
# clustering                     257           3                       3
# statistics                       3         234                       3
# machine-learning-model           3           3                     224

# %%
# Take out self-correlations to have a clearer view 
for i in range(top_used_relation.shape[0]):
    top_used_relation.iloc[i,i]= None

# Create a heatmap for paired-tags correlations 
sns.heatmap(top_used_relation)

# %% [markdown]
# # "Is deep learning just a fad?"

# %%
# Read in a new dataset with all of the questions ever asked on DSSE, their dates and tags.
all_questions = pd.read_csv('all_questions.csv')
all_questions.head()
# Out:
#       Id         CreationDate  \
# 0  45416  2019-02-12 00:36:29
# 1  45418  2019-02-12 00:50:39
# 2  45422  2019-02-12 04:40:51
# 3  45426  2019-02-12 04:51:49
# 4  45427  2019-02-12 05:08:24
#
#                                                 Tags
# 0      <python><keras><tensorflow><cnn><probability>
# 1                                   <neural-network>
# 2                      <python><ibm-watson><chatbot>
# 3                                            <keras>
# 4  <r><predictive-modeling><machine-learning-mode...

# %%
all_questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21576 entries, 0 to 21575
# Data columns (total 3 columns):
# Id              21576 non-null int64
# CreationDate    21576 non-null object
# Tags            21576 non-null object
# dtypes: int64(1), object(2)
# memory usage: 505.8+ KB

# %%
# Transform `Tags` column as in the previews dataset
all_questions['Tags'] = all_questions['Tags'].str.replace('^<|>$','').str.split('><')

# %% [markdown]
# * In exploring the most used tags from the dataset before, we can find tags that are related to deep learning. We will deem questions with these tags 'deep learning related'.

# %%
# Deep learning realated tags
dl_tags = ['lstm', 'cnn', 'scikit-learn', 'tensorflow', 'keras', 'neural-network', 'deep-learning']

# Create a new column for counting how many deep learning related tags are in the question  
all_questions['dl_tag_ct'] = 0

for i in range(all_questions.shape[0]):
        for t in all_questions.loc[i, 'Tags']:
            if t in dl_tags:
                all_questions.loc[i,'dl_tag_ct']+=1

# %%
# Convert CreationDate to datetime and keep only the year-month part since we are looking for trend in a monthly fashion 
all_questions['CreationYM'] = pd.to_datetime(all_questions['CreationDate']).dt.to_period('M')
all_questions['CreationYM'].head()
# Out:
# 0   2019-02
# 1   2019-02
# 2   2019-02
# 3   2019-02
# 4   2019-02
# Name: CreationYM, dtype: object

# %%
# Find rows that has more than zero dl_tag_ct and group by month to count how many deep learning related questions are asked per month
monthly_num = all_questions[all_questions['dl_tag_ct']!=0].groupby('CreationYM').size()

# Create a new df
monthly_num = pd.DataFrame(monthly_num, columns= ['dl_question_ct'])

# %%
# Find total number of questions asked by month
monthly_num['total_question_ct'] = all_questions.groupby('CreationYM').size()
# Percetage of deep learning questions asked by month 
monthly_num['pct%'] = round(monthly_num['dl_question_ct']/monthly_num['total_question_ct']*100,2)
monthly_num
# Out:
#             dl_question_ct  total_question_ct   pct%
# CreationYM
# 2014-05                  2                 58   3.45
# 2014-06                  7                 99   7.07
# 2014-07                  7                 76   9.21
# 2014-08                  5                 65   7.69
# 2014-09                  1                 48   2.08
# 2014-10                  7                 71   9.86
# 2014-11                  6                 64   9.38
# 2014-12                  8                 81   9.88
# 2015-01                  4                 63   6.35
# 2015-02                  6                 73   8.22
# 2015-03                  8                 54  14.81
# 2015-04                  6                 71   8.45
# 2015-05                 10                 92  10.87
# 2015-06                 12                121   9.92
# 2015-07                 15                117  12.82
# 2015-08                 14                101  13.86
# 2015-09                 16                 93  17.20
# 2015-10                 15                115  13.04
# 2015-11                 12                117  10.26
# 2015-12                 39                150  26.00
# 2016-01                 40                172  23.26
# 2016-02                 19                148  12.84
# 2016-03                 51                196  26.02
# 2016-04                 41                181  22.65
# 2016-05                 41                164  25.00
# 2016-06                 27                173  15.61
# 2016-07                 57                208  27.40
# 2016-08                 66                224  29.46
# 2016-09                 38                153  24.84
# 2016-10                 57                167  34.13
# ...                    ...                ...    ...
# 2017-08                104                294  35.37
# 2017-09                 61                195  31.28
# 2017-10                 86                236  36.44
# 2017-11                125                340  36.76
# 2017-12                142                322  44.10
# 2018-01                190                416  45.67
# 2018-02                166                385  43.12
# 2018-03                198                420  47.14
# 2018-04                170                446  38.12
# 2018-05                246                587  41.91
# 2018-06                150                415  36.14
# 2018-07                208                465  44.73
# 2018-08                258                540  47.78
# 2018-09                219                507  43.20
# 2018-10                178                461  38.61
# 2018-11                183                412  44.42
# 2018-12                170                421  40.38
# 2019-01                214                552  38.77
# 2019-02                307                712  43.12
# 2019-03                283                723  39.14
# 2019-04                300                746  40.21
# 2019-05                302                829  36.43
# 2019-06                333                818  40.71
# 2019-07                379                909  41.69
# 2019-08                292                766  38.12
# 2019-09                270                719  37.55
# 2019-10                250                645  38.76
# 2019-11                267                667  40.03
# 2019-12                292                724  40.33
# 2020-01                168                459  36.60
#
# [69 rows x 3 columns]

# %%
# Visulize above findings 
fig, ax = plt.subplots(figsize = (15,10))
sns.barplot(x = monthly_num.index, y = monthly_num['dl_question_ct'], ax = ax, palette="Blues", hue = monthly_num['pct%'])

for item in ax.get_xticklabels():
    item.set_rotation(90)
