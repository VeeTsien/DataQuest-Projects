# %% [markdown]
# # Predicting Bike Rentals
# ---
# The data compiled by [Hadi Fanaee-T](http://www.liaad.up.pt/area/fanaee) at [University of Porto](https://sigarra.up.pt/up/pt/web_base.gera_pagina?p_pagina=home) contains 17380 rows, with each row representing the number of bike rentals for a single hour of a single day in Washington, D.C. You can download the data from the University of [California, Irvine's website](http://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset).
#
# > *In this project, we'll try to predict the total number of bikes people rented in a given hour. We'll predict the cnt column using all of the other columns, except for casual and registered. To accomplish this, we'll create a few different machine learning models and evaluate their performance.*
#
# **Here are the descriptions for the relevant columns:**
# * `instant` - A unique sequential ID number for each row
# * `dteday` - The date of the rentals
# * `season` - The season in which the rentals occurred
# * `yr` - The year the rentals occurred
# * `mnth` - The month the rentals occurred
# * `hr` - The hour the rentals occurred
# * `holiday` - Whether or not the day was a holiday
# * `weekday` - The day of the week (as a number, 0 to 7)
# * `workingday` - Whether or not the day was a working day
# * `weathersit` - The weather (as a categorical variable)
# * `temp` - The temperature, on a 0-1 scale
# * `atemp` - The adjusted temperature
# * `hum` - The humidity, on a 0-1 scale
# * `windspeed` - The wind speed, on a 0-1 scale
# * `casual` - The number of casual riders (people who hadn't previously signed up with the bike sharing program)
# * `registered` - The number of registered riders (people who had already signed up)
# * `cnt` - The total number of bike rentals (casual + registered)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Read in & explore the dataset

# %%
bike_rentals = pd.read_csv('bike_rental_hour.csv')

# %%
bike_rentals.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
bike_rentals.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
bike_rentals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
# instant       17379 non-null int64
# dteday        17379 non-null object
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# casual        17379 non-null int64
# registered    17379 non-null int64
# cnt           17379 non-null int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
# Plot a histogram to see the distribution of cnt column
sns.set_style('dark')
sns.distplot(bike_rentals.cnt, kde = False, bins = 15)
plt.xlim(0, 1000)
# Out:
# (0, 1000)

# %%
# Explore correlations between cnt and all the other columns 
corr = bike_rentals.corr()

# Plot a heatmap to better show correlations 
fig = plt.figure(figsize = (10,8))
mask = corr == 1
heatmap = sns.heatmap(abs(corr), mask = mask, cmap = 'summer_r')
# heatmap.set_xticklabels(labels = corr.columns, rotation=30)

# %% [markdown]
# <div style="background-color:#f2f3f5; padding:15px"> From the heatmap above, we can tell that other than `casual` and `registered` -- which contain the values used to calculate `cnt`, so obviously there's a strong correlation -- the columns that are more strongly correlated to `cnt` are `hr`, `temp`, `atemp`, `hum`.</div>

# %% [markdown]
# ## Prep the dataset for training

# %%
# Function to label different hours in a day 
def assign_label(hour):
    if 6 < hour <= 12:
        return 1
    elif 12 < hour <= 18:
        return 2           
    elif 18 < hour <= 24:
        return 3
    else:
        return 4

# Create a new column
bike_rentals['time_label'] = bike_rentals.apply(lambda x: assign_label(x.hr), axis = 1)

# %%
# Split data into train, cross validation and test sets
from sklearn.model_selection import train_test_split
# Split the whole dataset for 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(bike_rentals.drop('cnt', axis = 1), 
                                                    bike_rentals.cnt,
                                                    test_size = 0.2,
                                                    random_state = 1)

# Split trainning set for final 60% train, 20% cross validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size = 0.25, random_state = 1)

# %%
# Check split result
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((10427, 17), (3476, 17), (3476, 17))

# %%
X_train.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'time_label'],
#       dtype='object')

# %%
# Pick features based on the heatmap we generated before
features = ['season', 'yr', 'mnth', 'hr', 'weathersit', 'temp', 'atemp', 
            'hum', 'windspeed', 'time_label']

# %% [markdown]
# ## Train & predict

# %% [markdown]
# ### Linear regression model

# %%
# Train & predict using Ridge model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lr = LinearRegression(normalize = True)
lr.fit(X_train[features], y_train)
preds_train = lr.predict(X_train[features])
preds_val = lr.predict(X_val[features])
mse_train = mean_squared_error(y_train, preds_train)
mse_val = mean_squared_error(y_val, preds_val)

print('''The training mse of the model is: {}, 
      The cross validation mse is: {}.'''.format(mse_train, mse_val))
# Out:
# The training mse of the model is: 16392.533780589492,
#       The cross validation mse is: 15720.812786104085.

# %%
# Plot learning curve
mses_train = []
mses_val = []
for i in range(1, 100):
    lr = LinearRegression(normalize = True)
    lr.fit(X_train[:i][features], y_train[:i])
    preds_train = lr.predict(X_train[features])
    preds_val = lr.predict(X_val[features])
    mse_train = mean_squared_error(y_train, preds_train)
    mse_val = mean_squared_error(y_val, preds_val)
    mses_train.append(mse_train)
    mses_val.append(mse_val)

# %%
plt.plot(range(1,100), mses_train, color = 'red')
plt.plot(range(1,100), mses_val, color = 'orange')
plt.ylim(1e4, 1e5)
# Out:
# (10000.0, 100000.0)

# %% [markdown]
# <div style="background-color:#f2f3f5; padding:15px"> From the results above, we can see that the training mse and cross validation mse errors are both really high. This indcates our model is underfitting.
# <br><br>
# We could try to add more features to the model and increase the complexity, or try a different model. We will try the latter method next.
# </div>

# %% [markdown]
# ### Dicision tree regressor

# %%
# Train & predict using decision tree model
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train[features], y_train)
tree_preds_train = dtr.predict(X_train[features])
tree_preds_val = dtr.predict(X_val[features])
tree_mse_train = mean_squared_error(y_train, tree_preds_train)
tree_mse_val = mean_squared_error(y_val, tree_preds_val)
print('''The training mse of the dicistion tree model is: {}, 
      The cross validation mse is: {}.'''.format(tree_mse_train, tree_mse_val))
# Out:
# The training mse of the dicistion tree model is: 50.40483040823503,
#       The cross validation mse is: 12992.66046541363.

# %% [markdown]
# <div style="background-color:#f2f3f5; padding:15px"> Without any parameter tweaking, the single decision tree model has a very low training error but really high cross validation error. This strongly indicates that our model is overfitting.
# <br><br>
# Next, let's tweak some parameters and see how the training and cross validation errors change.
# </div>

# %%
# Train & predict using decision tree model and tweak parameters
for leaf_num in range(5, 20):
    dtr = DecisionTreeRegressor(min_samples_leaf=leaf_num, random_state=1)
    dtr.fit(X_train[features], y_train)
    tree_preds_train = dtr.predict(X_train[features])
    tree_preds_val = dtr.predict(X_val[features])
    tree_mse_train = mean_squared_error(y_train, tree_preds_train)
    tree_mse_val = mean_squared_error(y_val, tree_preds_val)
    print('''With a minimum leaf number of {}, the training mse of the dicistion tree model is: {} | 
    The cross validation mse is: {}.'''.format(leaf_num, tree_mse_train, tree_mse_val), 
          '\n', '*'*30)
# Out:
# With a minimum leaf number of 5, the training mse of the dicistion tree model is: 4104.481083132631 | The cross validation mse is: 9827.915324878299.
#  ******************************
# With a minimum leaf number of 6, the training mse of the dicistion tree model is: 4613.901662305971 | The cross validation mse is: 9457.242926091765.
#  ******************************
# With a minimum leaf number of 7, the training mse of the dicistion tree model is: 4949.641102782483 | The cross validation mse is: 9263.222377124925.
#  ******************************
# With a minimum leaf number of 8, the training mse of the dicistion tree model is: 5207.798588299773 | The cross validation mse is: 8914.112090801511.
#  ******************************
# With a minimum leaf number of 9, the training mse of the dicistion tree model is: 5408.426742939888 | The cross validation mse is: 8606.204492489916.
#  ******************************
# With a minimum leaf number of 10, the training mse of the dicistion tree model is: 5665.689343620015 | The cross validation mse is: 8571.204218581068.
#  ******************************
# With a minimum leaf number of 11, the training mse of the dicistion tree model is: 5868.0609214296865 | The cross validation mse is: 8539.441666846471.
#  ******************************
# With a minimum leaf number of 12, the training mse of the dicistion tree model is: 6075.556316655506 | The cross validation mse is: 8427.755138052204.
#  ******************************
# With a minimum leaf number of 13, the training mse of the dicistion tree model is: 6167.809153405228 | The cross validation mse is: 8312.323969509276.
#  ******************************
# With a minimum leaf number of 14, the training mse of the dicistion tree model is: 6284.030085622549 | The cross validation mse is: 8307.104419091176.
#  ******************************
# With a minimum leaf number of 15, the training mse of the dicistion tree model is: 6361.915733020754 | The cross validation mse is: 8319.622667058788.
#  ******************************
# With a minimum leaf number of 16, the training mse of the dicistion tree model is: 6461.0642045437635 | The cross validation mse is: 8245.954628671569.
#  ******************************
# With a minimum leaf number of 17, the training mse of the dicistion tree model is: 6626.224297847237 | The cross validation mse is: 8210.330125684235.
#  ******************************
# With a minimum leaf number of 18, the training mse of the dicistion tree model is: 6714.320015781224 | The cross validation mse is: 8119.338933638261.
#  ******************************
# With a minimum leaf number of 19, the training mse of the dicistion tree model is: 6787.792478625228 | The cross validation mse is: 8113.210129693937.
#  ******************************

# %%
# Using the best min_samples_leaf value, experiment with max_depth parameter
for depth in range(2, 15):
    dtr = DecisionTreeRegressor(min_samples_leaf=19, max_depth=depth, random_state=1)
    dtr.fit(X_train[features], y_train)
    tree_preds_train = dtr.predict(X_train[features])
    tree_preds_val = dtr.predict(X_val[features])
    tree_mse_train = mean_squared_error(y_train, tree_preds_train)
    tree_mse_val = mean_squared_error(y_val, tree_preds_val)
    print('''With a minimum leaf number of 19, and the max depth of {}, 
    the training mse of the dicistion tree model is: {} | 
    The cross validation mse is: {}.'''.format(depth, tree_mse_train, tree_mse_val), 
          '\n', '*'*30)
# Out:
# With a minimum leaf number of 19, and the max depth of 2,
#     the training mse of the dicistion tree model is: 19732.51378627246 |
#     The cross validation mse is: 18233.801468025704.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 3,
#     the training mse of the dicistion tree model is: 16894.142172026743 |
#     The cross validation mse is: 16278.501232608107.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 4,
#     the training mse of the dicistion tree model is: 14398.79083502228 |
#     The cross validation mse is: 14001.005996035043.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 5,
#     the training mse of the dicistion tree model is: 11960.432573363782 |
#     The cross validation mse is: 11433.478909772992.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 6,
#     the training mse of the dicistion tree model is: 10623.084124481788 |
#     The cross validation mse is: 10304.260617230877.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 7,
#     the training mse of the dicistion tree model is: 9310.309426268088 |
#     The cross validation mse is: 9045.273988515864.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 8,
#     the training mse of the dicistion tree model is: 8375.42525840426 |
#     The cross validation mse is: 8264.49653361452.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 9,
#     the training mse of the dicistion tree model is: 7692.738655867216 |
#     The cross validation mse is: 7996.980374062196.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 10,
#     the training mse of the dicistion tree model is: 7359.920390549287 |
#     The cross validation mse is: 8130.153649698422.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 11,
#     the training mse of the dicistion tree model is: 7188.157911056005 |
#     The cross validation mse is: 8043.434095318657.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 12,
#     the training mse of the dicistion tree model is: 7051.7306330231195 |
#     The cross validation mse is: 8050.108110913257.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 13,
#     the training mse of the dicistion tree model is: 6942.319930919592 |
#     The cross validation mse is: 8096.044150960478.
#  ******************************
# With a minimum leaf number of 19, and the max depth of 14,
#     the training mse of the dicistion tree model is: 6883.997848950683 |
#     The cross validation mse is: 8066.035881635416.
#  ******************************

# %% [markdown]
# <div style="background-color:#f2f3f5; padding:15px"> As we can see from the results above, with some parameter tweaking, we were able to decrease both the cross validation error and the gap between training and cross validation errors dramatically.
# </div>
#
# |Parameter|Training error|Cross validation error|
# |-|-|-|
# |none|50.4|12992.6|
# |min_samples_leaf|6787.8|8103.5|
# |min_samples_leaf, max_depth|7692.7|7996.98|
# <br>
# <div style="background-color:#f2f3f5; padding:15px">
# Next, we will try out RandomForestRegressor on our data.
# </div>

# %% [markdown]
# ### Random forest regressor

# %%
# Train & predict with no parameter tweak
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=1)
rfr.fit(X_train[features], y_train)
train_preds_rfr = rfr.predict(X_train[features])
val_preds_rfr = rfr.predict(X_val[features])
mse_train_rfr = mean_squared_error(y_train, train_preds_rfr)
mse_val_rfr = mean_squared_error(y_val, val_preds_rfr)
print('''The training mse of the random forest model is: {}, 
      The cross validation mse is: {}.'''.format(mse_train_rfr, mse_val_rfr))
# Out:
# The training mse of the random forest model is: 1487.595186926702,
#       The cross validation mse is: 7984.305374144132.

# %%
# Train & predict using random forest model and tweak parameters
mses_train_rfr = []
mses_val_rfr = []
for leaf_num in range(5, 20):
    rfr = RandomForestRegressor(min_samples_leaf=leaf_num, random_state=1)
    rfr.fit(X_train[features], y_train)
    train_preds_rfr = rfr.predict(X_train[features])
    val_preds_rfr = rfr.predict(X_val[features])
    mse_train_rfr = mean_squared_error(y_train, train_preds_rfr)
    mse_val_rfr = mean_squared_error(y_val, val_preds_rfr)
    mses_train_rfr.append(mse_train_rfr)
    mses_val_rfr.append(mse_val_rfr)
    print('''With a minimum leaf number of {}, the training mse of the dicistion tree model is: {} | 
    The cross validation mse is: {}.'''.format(leaf_num, mse_train_rfr, mse_val_rfr), 
          '\n', '*'*30)
# Out:
# With a minimum leaf number of 5, the training mse of the dicistion tree model is: 4357.60556709831 |
#     The cross validation mse is: 7525.468284167501.
#  ******************************
# With a minimum leaf number of 6, the training mse of the dicistion tree model is: 4750.093131261507 |
#     The cross validation mse is: 7469.814645671032.
#  ******************************
# With a minimum leaf number of 7, the training mse of the dicistion tree model is: 5047.129535256226 |
#     The cross validation mse is: 7394.852975016654.
#  ******************************
# With a minimum leaf number of 8, the training mse of the dicistion tree model is: 5324.738189235592 |
#     The cross validation mse is: 7404.569947279587.
#  ******************************
# With a minimum leaf number of 9, the training mse of the dicistion tree model is: 5524.45684793211 |
#     The cross validation mse is: 7337.45274346178.
#  ******************************
# With a minimum leaf number of 10, the training mse of the dicistion tree model is: 5679.452198250476 |
#     The cross validation mse is: 7314.854724594898.
#  ******************************
# With a minimum leaf number of 11, the training mse of the dicistion tree model is: 5862.700740361354 |
#     The cross validation mse is: 7312.1515157095555.
#  ******************************
# With a minimum leaf number of 12, the training mse of the dicistion tree model is: 6027.008082807905 |
#     The cross validation mse is: 7376.775756083544.
#  ******************************
# With a minimum leaf number of 13, the training mse of the dicistion tree model is: 6194.683198674489 |
#     The cross validation mse is: 7390.46444851733.
#  ******************************
# With a minimum leaf number of 14, the training mse of the dicistion tree model is: 6311.683424988786 |
#     The cross validation mse is: 7409.591342849136.
#  ******************************
# With a minimum leaf number of 15, the training mse of the dicistion tree model is: 6401.362648133381 |
#     The cross validation mse is: 7420.377441517414.
#  ******************************
# With a minimum leaf number of 16, the training mse of the dicistion tree model is: 6507.656826748485 |
#     The cross validation mse is: 7388.823282169136.
#  ******************************
# With a minimum leaf number of 17, the training mse of the dicistion tree model is: 6621.679236310461 |
#     The cross validation mse is: 7430.224060670236.
#  ******************************
# With a minimum leaf number of 18, the training mse of the dicistion tree model is: 6726.024711338444 |
#     The cross validation mse is: 7446.834994972478.
#  ******************************
# With a minimum leaf number of 19, the training mse of the dicistion tree model is: 6782.61491951401 |
#     The cross validation mse is: 7420.621019622257.
#  ******************************

# %%
plt.plot(range(5, 20), mses_train_rfr, color = 'red', label = 'training error')
plt.plot(range(5, 20), mses_val_rfr, color = 'green', label = 'cross validation error')
plt.xlabel('min_samples_leaf')
plt.ylabel('mean squared error')
plt.legend(loc = 'lower right')

# %% [markdown]
# <div style="background-color:#f2f3f5; padding:15px">
# From the plot above, we can find the optimal value for min_sample_leaf is around 11. Let's use that to try out other parameteres.
# <br><br>
# We will tune our model and experiment with n_estimators last since it's more time consuming.
# </div>

# %%
# Experiment with max_depth with bootstrap set to True
mses_train_d = []
mses_val_d = []
for depth in range(2,15): 
    rfr = RandomForestRegressor(max_depth = depth, min_samples_leaf=11, random_state=1, bootstrap = True)
    rfr.fit(X_train[features], y_train)
    train_preds_rfr = rfr.predict(X_train[features])
    val_preds_rfr = rfr.predict(X_val[features])
    mse_train_rfr = mean_squared_error(y_train, train_preds_rfr)
    mse_val_rfr = mean_squared_error(y_val, val_preds_rfr)
    mses_train_d.append(mse_train_rfr)
    mses_val_d.append(mse_val_rfr)
    print('''With max_depth {}, and a minimum leaf number of 11, the training mse of the dicistion tree model is: {} | 
    The cross validation mse is: {}.'''.format(depth, mse_train_rfr, mse_val_rfr), 
          '\n', '*'*30)
# Out:
# With max_depth 2, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 19596.868730445192 |
#     The cross validation mse is: 18052.38051398432.
#  ******************************
# With max_depth 3, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 16753.939730966395 |
#     The cross validation mse is: 16070.766285867096.
#  ******************************
# With max_depth 4, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 14149.365946785618 |
#     The cross validation mse is: 13678.314546463762.
#  ******************************
# With max_depth 5, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 11568.089549271868 |
#     The cross validation mse is: 11059.067558043025.
#  ******************************
# With max_depth 6, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 9860.28759358744 |
#     The cross validation mse is: 9605.916049796797.
#  ******************************
# With max_depth 7, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 8727.035471977217 |
#     The cross validation mse is: 8527.955164111212.
#  ******************************
# With max_depth 8, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7741.805920673346 |
#     The cross validation mse is: 7798.983214191518.
#  ******************************
# With max_depth 9, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7052.811754333605 |
#     The cross validation mse is: 7524.357282972347.
#  ******************************
# With max_depth 10, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 6619.233271316627 |
#     The cross validation mse is: 7430.789507867638.
#  ******************************
# With max_depth 11, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 6359.64179604776 |
#     The cross validation mse is: 7366.926049898356.
#  ******************************
# With max_depth 12, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 6174.553532334898 |
#     The cross validation mse is: 7335.491640458882.
#  ******************************
# With max_depth 13, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 6047.18452678951 |
#     The cross validation mse is: 7306.276813308211.
#  ******************************
# With max_depth 14, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 5950.931842048164 |
#     The cross validation mse is: 7303.924343478403.
#  ******************************

# %%
plt.plot(range(2, 15), mses_train_d, color = 'red', label = 'training error')
plt.plot(range(2, 15), mses_val_d, color = 'green', label = 'cross validation error')
plt.xlabel('max_depth')
plt.ylabel('mean squared error')
plt.legend(loc = 'upper right')

# %% [markdown]
# <div style="background-color:#f2f3f5; padding:15px">
# From the plot above, we can find the optimal value for max_depth is 8, where training error and cross validation error converges. Let's use that to try out n_estimators.
# </div>

# %%
# Experiment with n_estimator with bootstrap set to True
# Train & predict using random forest model and tweak parameters
mses_train_e = []
mses_val_e = []
for n in range(100, 200, 10): # increment estimator by 10 from 100 to 200
    rfr = RandomForestRegressor(n_estimators = n, min_samples_leaf=11, max_depth = 8, random_state=1, bootstrap = True)
    rfr.fit(X_train[features], y_train)
    train_preds_rfr = rfr.predict(X_train[features])
    val_preds_rfr = rfr.predict(X_val[features])
    mse_train_rfr = mean_squared_error(y_train, train_preds_rfr)
    mse_val_rfr = mean_squared_error(y_val, val_preds_rfr)
    mses_train_e.append(mse_train_rfr)
    mses_val_e.append(mse_val_rfr)
    print('''With {} estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: {} | 
    The cross validation mse is: {}.'''.format(n, mse_train_rfr, mse_val_rfr), 
          '\n', '*'*30)
# Out:
# With 100 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7599.758082207936 |
#     The cross validation mse is: 7753.615042058185.
#  ******************************
# With 110 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7607.0619209546885 |
#     The cross validation mse is: 7763.079453903965.
#  ******************************
# With 120 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7604.949763332134 |
#     The cross validation mse is: 7759.706095563488.
#  ******************************
# With 130 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7604.169830924964 |
#     The cross validation mse is: 7759.578798849383.
#  ******************************
# With 140 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7604.805302475717 |
#     The cross validation mse is: 7755.13223884346.
#  ******************************
# With 150 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7602.290278742132 |
#     The cross validation mse is: 7759.930446571911.
#  ******************************
# With 160 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7601.325931490383 |
#     The cross validation mse is: 7756.214733484934.
#  ******************************
# With 170 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7603.432843108069 |
#     The cross validation mse is: 7750.591391971207.
#  ******************************
# With 180 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7596.212556337346 |
#     The cross validation mse is: 7740.7814948892965.
#  ******************************
# With 190 estimators, and a minimum leaf number of 11, the training mse of the dicistion tree model is: 7600.374823875937 |
#     The cross validation mse is: 7742.55589096458.
#  ******************************

# %%
plt.plot(range(100, 200, 10), mses_train_e, color = 'red', label = 'training error')
plt.plot(range(100, 200, 10), mses_val_e, color = 'green', label = 'cross validation error')
plt.xlabel('n_esitmator')
plt.ylabel('mean squared error')
plt.legend(loc = 'center')

# %% [markdown]
# Let's use our best tuned model to actually predict some bike rentals.

# %%
# Predict bike rentals 
model = RandomForestRegressor(n_estimators = 180, min_samples_leaf=11, 
                              max_depth = 8, random_state=1, bootstrap = True)
model.fit(X_train[features], y_train)
predictions = model.predict(X_test[features])

# %%
# Plot prediction vs actual values on part of the data
fig = plt.figure(figsize = (20,10))
plt.plot(range(len(X_test[:300])), predictions[:300], color = 'orange', label = 'predictions', alpha = 0.6)
plt.plot(range(len(X_test[:300])), y_test[:300], color = 'green', label = 'actual', alpha = 0.3)
plt.xlim(0, )
plt.ylabel('count')
plt.legend()

# %% [markdown]
# <div style="background-color:#f2f3f5; padding:15px">
# From the plot above, it looks like our model is failling in predicting the high counts, which are the right skewed outliers in the histogram we plotted at the begining of our project. But the predictions fits the actual values mostly.
# </div>

# %% [markdown]
# # Conclusion:
# <div style="background-color:#f2f3f5; padding:15px">
# The best results for the three models we tried in this project are as below:
# </div>
#
# |Model|Training error|Cross validation error|
# |-|-|-|
# |Linear Regression|16392.5|15720.8|
# |Decision Tree Regressor|7692.7|7996.98|
# |Random Forest Regressor|7596.2|7740.8|
#
# <br>
#
# *<div style="background-color:#f2f3f5; padding:15px">
# It's pretty clear that RandomForest is best at predition accuracy.While the random forest algorithm is incredibly powerful, it isn't applicable to all tasks.
#
# The main strengths of a random forest are:
#
# * Very accurate predictions - Random forests achieve near state-of-the-art performance on many machine learning tasks. Along with neural networks and gradient-boosted trees, they're typically one of the top-performing algorithms.
# * Resistance to overfitting - Due to their construction, random forests are fairly resistant to overfitting. We still need to set and tweak parameters like max_depth though.
#
# The main weaknesses of using a random forest are:
#
# * They're difficult to interpret - Because we're averaging the results of many trees, it can be hard to figure out why a random forest is making predictions the way it is.
# * They take longer to create - Making two trees takes twice as long as making one, making three takes three times as long, and so on. Fortunately, we can exploit multicore processors to parallelize tree construction. Scikit allows us to do this through the n_jobs parameter on RandomForestClassifier.
#
# </div>*
